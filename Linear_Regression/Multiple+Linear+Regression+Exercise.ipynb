# %% [markdown]
# # Multiple Linear Regression - Exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size_year.csv'.
#
# You are expected to create a multiple linear regression (similar to the one in the lecture), using the new data.
#
# In this exercise, the dependent variable is 'price', while the independent variables are 'size' and 'year'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('C:/Users/HP/Downloads/Data_sets/real_estate_price_size_year.csv')

# %%
data
# Out:
#          price     size  year
# 0   234314.144   643.09  2015
# 1   228581.528   656.22  2009
# 2   281626.336   487.29  2018
# 3   401255.608  1504.75  2015
# 4   458674.256  1275.46  2009
# ..         ...      ...   ...
# 95  252460.400   549.80  2009
# 96  310522.592  1037.44  2009
# 97  383635.568  1504.75  2006
# 98  225145.248   648.29  2015
# 99  274922.856   705.29  2006
#
# [100 rows x 3 columns]

# %%
data.describe()
# Out:
#                price         size         year
# count     100.000000   100.000000   100.000000
# mean   292289.470160   853.024200  2012.600000
# std     77051.727525   297.941951     4.729021
# min    154282.128000   479.750000  2006.000000
# 25%    234280.148000   643.330000  2009.000000
# 50%    280590.716000   696.405000  2015.000000
# 75%    335723.696000  1029.322500  2018.000000
# max    500681.128000  1842.510000  2018.000000

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
x1 = data[['size','year']]
y = data['price']

# %% [markdown]
# ### Regression

# %%
x = sm.add_constant(x1)
result = sm.OLS(y, x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     168.5
# Date:                Wed, 23 Aug 2023   Prob (F-statistic):           2.77e-32
# Time:                        01:10:06   Log-Likelihood:                -1191.7
# No. Observations:                 100   AIC:                             2389.
# Df Residuals:                      97   BIC:                             2397.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.772e+06   1.58e+06     -3.647      0.000   -8.91e+06   -2.63e+06
# ...

# %% [markdown]
# This suggests that the both the independant variables equally effect the price

# %% [markdown]
# #### To see the independant effect of each variable over the dependent variable we would see the graphical representation

# %%
x2 = data['size']
xo = sm.add_constant(x2)
result2 = sm.OLS(y, xo).fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Wed, 23 Aug 2023   Prob (F-statistic):           8.13e-31
# Time:                        01:10:06   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# ...

# %%
plt.scatter(x2, y)
regression_line = 1.019e+05 + 223.1787 * x2
plt.plot(x2, regression_line, color = 'red')

# %%
x3 = data['year']
xo2 = sm.add_constant(x3)
result3 = sm.OLS(y, xo2).fit()
result3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8553
# Date:                Wed, 23 Aug 2023   Prob (F-statistic):              0.357
# Time:                        01:10:06   Log-Likelihood:                -1266.2
# No. Observations:                 100   AIC:                             2536.
# Df Residuals:                      98   BIC:                             2542.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.758e+06    3.3e+06     -0.836      0.405    -9.3e+06    3.79e+06
# ...

# %%
plt.scatter(x3, y)
regression_line = -2.758e+06 + 1515.5137 * x3
plt.plot(x3, regression_line, color = 'red')

# %% [markdown]
# #### Comparing the two models:
#
# 1. The model with both "size" and "year" has a higher adjusted R-squared value, indicating that it explains more of the variation in real estate prices compared to the model with only "size."
#
# 2. Including the "year" predictor seems to contribute to the model's explanatory power, suggesting that "year" provides additional information that helps improve the model's predictions.

# %% [markdown]
# ### Dealing with the Dummy variable that is Attendance in this case which shows the attendance of student above or below 75 % with yes and no respectively

# %%
data = pd.read_csv('C:/Users/HP/Downloads/Data_sets/1.03.+Dummies.csv')
data
# Out:
#      SAT   GPA Attendance
# 0   1714  2.40         No
# 1   1664  2.52         No
# 2   1760  2.54         No
# 3   1685  2.74         No
# 4   1693  2.83         No
# ..   ...   ...        ...
# 79  1936  3.71        Yes
# 80  1810  3.71        Yes
# 81  1987  3.73         No
# 82  1962  3.76        Yes
# 83  2050  3.81        Yes
#
# [84 rows x 3 columns]

# %%
# WE mapped the yes with a new value that is 1 and no with a 0
data['Attendance'] = data['Attendance'].map({'Yes':1, 'No':0})
data.describe()
# Out:
#                SAT        GPA  Attendance
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    0.464286
# std     104.530661   0.271617    0.501718
# min    1634.000000   2.400000    0.000000
# 25%    1772.000000   3.190000    0.000000
# 50%    1846.000000   3.380000    0.000000
# 75%    1934.000000   3.502500    1.000000
# max    2050.000000   3.810000    1.000000

# %%
data.describe()
# Out:
#                SAT        GPA  Attendance
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    0.464286
# std     104.530661   0.271617    0.501718
# min    1634.000000   2.400000    0.000000
# 25%    1772.000000   3.190000    0.000000
# 50%    1846.000000   3.380000    0.000000
# 75%    1934.000000   3.502500    1.000000
# max    2050.000000   3.810000    1.000000

# %%
y = data['GPA']
x1 = data[['SAT', 'Attendance']]
x = sm.add_constant(x1)
result = sm.OLS(y, x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     52.70
# Date:                Wed, 23 Aug 2023   Prob (F-statistic):           2.19e-15
# Time:                        01:10:07   Log-Likelihood:                 25.798
# No. Observations:                  84   AIC:                            -45.60
# Df Residuals:                      81   BIC:                            -38.30
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6439      0.358      1.797      0.076      -0.069       1.357
# ...

# %% [markdown]
#  GPA = const + SAT * 0.0014 + Attendance * 0.2226
#
#  With no attendence
#  GPA = 0.6439 + SAT * 0.0014
#
#  With attendance
#  GPA = 0.8665 + SAT * 0.0014
#
#  Witout considering the attendance
#  GPA = 0.275 + SAT * 0.0017

# %%
plt.scatter(data['SAT'] , y, c = data['Attendance'], cmap = 'RdYlGn_r')

yhat_no = 0.6439 + data['SAT'] * 0.0014
yhat_yes = 0.8665 + data['SAT'] * 0.0014
no_attend = 0.275 + data['SAT'] * 0.0017

plt.plot(data['SAT'], yhat_no, color = 'green', label = 'less than 75%')
plt.plot(data['SAT'], yhat_yes, color = 'red', label = 'more than 75%')
plt.plot(data['SAT'], no_attend, color = 'blue', label = 'attendance not included')

plt.legend(title = 'Attendance')

# %% [markdown]
# #### Now lets predict gpa for the for random numbers

# %%
x.head(5)
# Out:
#    const   SAT  Attendance
# 0    1.0  1714           0
# 1    1.0  1664           0
# 2    1.0  1760           0
# 3    1.0  1685           0
# 4    1.0  1693           0

# %%
new_data = pd.DataFrame({'const':[1,1],'SAT':[1780, 1670], 'Attendance':[0, 1]})
new = result.predict(new_data)
new.name = 'predicted GPA'
concatented_data = pd.concat([new_data, new] , axis = 1)

# %%
concatented_data
# Out:
#    const   SAT  Attendance  predicted GPA
# 0      1  1780           0       3.135497
# 1      1  1670           1       3.204163
